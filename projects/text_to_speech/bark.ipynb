# %%
import pdfplumber
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# %%
preload_models()
# Out:
# No GPU being used. Careful, inference might be very slow!
# Downloading text_2.pt: 100%|██████████████████████████████████████████████████████| 5.35G/5.35G [01:31<00:00, 58.5MB/s]
# C:\Users\ajfon\Documents\virtuals\text_to_audio\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ajfon. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)okenizer_config.json: 100%|██████████████████████████████████████████████████| 29.0/29.0 [00:00<?, ?B/s]
# C:\Users\ajfon\Documents\virtuals\text_to_audio\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ajfon\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)solve/main/vocab.txt: 100%|██████████████████████████████████████████| 996k/996k [00:00<00:00, 4.82MB/s]
# Downloading (…)/main/tokenizer.json: 100%|████████████████████████████████████████| 1.96M/1.96M [00:00<00:00, 7.01MB/s]
# Downloading (…)lve/main/config.json: 100%|█████████████████████████████████████████████| 625/625 [00:00<00:00, 209kB/s]
# Downloading coarse_2.pt: 100%|████████████████████████████████████████████████████| 3.93G/3.93G [01:02<00:00, 62.7MB/s]
# Downloading fine_2.pt: 100%|██████████████████████████████████████████████████████| 3.74G/3.74G [01:03<00:00, 59.2MB/s]
# C:\Users\ajfon\Documents\virtuals\text_to_audio\Lib\site-packages\torch\nn\utils\weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to C:\Users\ajfon/.cache\torch\hub\checkpoints\encodec_24khz-d7cc33bc.th
# 100%|█████████████████████████████████████████████████████████████████████████████| 88.9M/88.9M [00:01<00:00, 56.5MB/s]

# %%
# generate audio from text
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [laughs] 
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 613/613 [01:20<00:00,  7.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [06:25<00:00, 12.42s/it]

# %%
text_prompt = """
    The human understanding is no dry light, but receives an infusion from the will and affections;
    whence proceed sciences which may be called sciences as one would. For what a man had rather
    were true he more readily believes. Therefore he rejects difficult things from impatience of research;
    sober things, because they narrow hope; the deeper things of nature, from superstition; the light
    of experience, from arrogance and pride, lest his mind should seem to be occupied with things
    mean and transitory; things not commonly believed, out of deference to the opinion of the vulgar.
    Numberless in short are the ways, and sometimes imperceptible, in which the affections colour
    and infect the understanding.
"""

audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bacon.wav", SAMPLE_RATE, audio_array)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 571/571 [01:09<00:00,  8.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [05:36<00:00, 11.61s/it]

# %%
# !pip install TTS
# Out:
# Collecting TTS
#   Downloading TTS-0.19.1.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 8.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cython==0.29.30
#   Downloading Cython-0.29.30-py2.py3-none-any.whl (985 kB)
#      ------------------------------------- 985.1/985.1 kB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.11.2 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from TTS) (1.11.3)
# Requirement already satisfied: torch>=1.7 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from TTS) (2.1.0)
# Requirement already satisfied: torchaudio in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from TTS) (2.1.0)
# Collecting soundfile==0.12.*
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 32.2 MB/s eta 0:00:00
# Collecting librosa==0.10.*
#   Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#      ------------------------------------- 253.7/253.7 kB 15.2 MB/s eta 0:00:00
# Collecting scikit-learn==1.3.0
#   Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 34.7 MB/s eta 0:00:00
# Collecting inflect==5.6.*
#   Downloading inflect-5.6.2-py3-none-any.whl (33 kB)
# Collecting tqdm==4.64.*
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Collecting anyascii==0.3.*
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ------------------------------------- 289.9/289.9 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml==6.* in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from TTS) (6.0.1)
# Collecting fsspec==2023.6.0
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ------------------------------------- 163.8/163.8 kB 10.2 MB/s eta 0:00:00
# Collecting aiohttp==3.8.*
#   Downloading aiohttp-3.8.6-cp311-cp311-win_amd64.whl (322 kB)
#      ------------------------------------- 322.6/322.6 kB 20.8 MB/s eta 0:00:00
# Collecting packaging==23.1
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting flask==2.*
#   Using cached flask-2.3.3-py3-none-any.whl (96 kB)
# Collecting pysbd==0.3.4
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.1/71.1 kB 4.1 MB/s eta 0:00:00
# Collecting umap-learn==0.5.*
#   Downloading umap-learn-0.5.4.tar.gz (90 kB)
#      ---------------------------------------- 90.8/90.8 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas<2.0,>=1.4
#   Downloading pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
#      --------------------------------------- 10.3/10.3 MB 43.7 MB/s eta 0:00:00
# Collecting matplotlib==3.7.*
#   Downloading matplotlib-3.7.3-cp311-cp311-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 48.1 MB/s eta 0:00:00
# Collecting trainer
#   Downloading trainer-0.0.31-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.6/50.6 kB ? eta 0:00:00
# Collecting coqpit>=0.0.16
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      --------------------------------------- 19.2/19.2 MB 46.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pypinyin
#   Downloading pypinyin-0.49.0-py2.py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 43.7 MB/s eta 0:00:00
# Collecting gruut[de,es,fr]==2.2.3
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jamo
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 12.0 MB/s eta 0:00:00
# Collecting g2pkk>=0.1.1
#   Downloading g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Collecting bangla
#   Downloading bangla-0.0.2-py2.py3-none-any.whl (6.2 kB)
# Collecting bnnumerizer
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting bnunicodenormalizer
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting k-diffusion
#   Downloading k_diffusion-0.1.1-py3-none-any.whl (33 kB)
# Collecting einops==0.6.*
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.2/42.2 kB 2.0 MB/s eta 0:00:00
# Collecting transformers==4.33.*
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: encodec==0.1.* in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from TTS) (0.1.1)
# Collecting unidecode==1.3.*
#   Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#      ---------------------------------------- 235.5/235.5 kB ? eta 0:00:00
# Collecting numpy==1.24.3
#   Downloading numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
#      --------------------------------------- 14.8/14.8 MB 54.7 MB/s eta 0:00:00
# Collecting numba==0.57.0
#   Downloading numba-0.57.0-cp311-cp311-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from aiohttp==3.8.*->TTS) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from aiohttp==3.8.*->TTS) (3.3.1)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp311-cp311-win_amd64.whl (60 kB)
#      ---------------------------------------- 60.2/60.2 kB 3.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp311-cp311-win_amd64.whl (44 kB)
#      ---------------------------------------- 44.9/44.9 kB 2.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting Werkzeug>=2.3.7
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      ---------------------------------------- 226.7/226.7 kB ? eta 0:00:00
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from flask==2.*->TTS) (3.1.2)
# Collecting itsdangerous>=2.1.2
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.13.1)
# Collecting dateparser~=1.1.0
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ---------------------------------------- 293.8/293.8 kB ? eta 0:00:00
# Collecting gruut-ipa<1.0,>=0.12.0
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      -------------------------------------- 101.6/101.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gruut_lang_en~=2.0.0
#   Downloading gruut_lang_en-2.0.0.tar.gz (15.2 MB)
#      --------------------------------------- 15.2/15.2 MB 50.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jsonlines~=1.2.0
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Collecting networkx<3.0.0,>=2.5.0
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 42.9 MB/s eta 0:00:00
# Collecting num2words<1.0.0,>=0.5.10
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      -------------------------------------- 143.3/143.3 kB 8.3 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7
#   Downloading python-crfsuite-0.9.9.tar.gz (440 kB)
#      ------------------------------------- 440.8/440.8 kB 28.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gruut_lang_de~=2.0.0
#   Downloading gruut_lang_de-2.0.0.tar.gz (18.1 MB)
#      --------------------------------------- 18.1/18.1 MB 46.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gruut_lang_es~=2.0.0
#   Downloading gruut_lang_es-2.0.0.tar.gz (31.4 MB)
#      --------------------------------------- 31.4/31.4 MB 40.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gruut_lang_fr~=2.0.0
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      --------------------------------------- 10.9/10.9 MB 54.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Collecting joblib>=0.14
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      -------------------------------------- 302.2/302.2 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from librosa==0.10.*->TTS) (5.1.1)
# Collecting pooch>=1.0
#   Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.7-cp311-cp311-win_amd64.whl (184 kB)
#      ---------------------------------------- 184.7/184.7 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from librosa==0.10.*->TTS) (4.8.0)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting msgpack>=1.0
#   Downloading msgpack-1.0.7-cp311-cp311-win_amd64.whl (222 kB)
#      ------------------------------------- 222.9/222.9 kB 13.3 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp311-cp311-win_amd64.whl (480 kB)
#      ------------------------------------- 480.5/480.5 kB 31.4 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.43.1-cp311-cp311-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 45.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from matplotlib==3.7.*->TTS) (10.1.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.1/103.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from matplotlib==3.7.*->TTS) (2.8.2)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp311-cp311-win_amd64.whl (27.7 MB)
#      --------------------------------------- 27.7/27.7 MB 36.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: cffi>=1.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from soundfile==0.12.*->TTS) (1.16.0)
# Requirement already satisfied: colorama in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from tqdm==4.64.*->TTS) (0.4.6)
# Requirement already satisfied: filelock in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from transformers==4.33.*->TTS) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from transformers==4.33.*->TTS) (0.17.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from transformers==4.33.*->TTS) (2023.10.3)
# Requirement already satisfied: requests in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from transformers==4.33.*->TTS) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp311-cp311-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from transformers==4.33.*->TTS) (0.4.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 36.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ------------------------------------- 502.5/502.5 kB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: sympy in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from torch>=1.7->TTS) (1.12)
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ---------------------------------------- 261.4/261.4 kB ? eta 0:00:00
# Collecting clean-fid
#   Downloading clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Collecting clip-anytorch
#   Downloading clip_anytorch-2.5.2-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 43.9 MB/s eta 0:00:00
# Collecting dctorch
#   Downloading dctorch-0.1.2-py3-none-any.whl (2.3 kB)
# Collecting jsonmerge
#   Downloading jsonmerge-1.9.2-py3-none-any.whl (19 kB)
# Collecting kornia
#   Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#      ------------------------------------- 705.7/705.7 kB 21.7 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp311-cp311-win_amd64.whl (24.5 MB)
#      --------------------------------------- 24.5/24.5 MB 32.8 MB/s eta 0:00:00
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting torchsde
#   Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Collecting torchvision
#   Downloading torchvision-0.16.0-cp311-cp311-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 26.7 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from trainer->TTS) (5.9.6)
# Collecting tensorboard
#   Downloading tensorboard-2.15.0-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from cffi>=1.0->soundfile==0.12.*->TTS) (2.21)
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from Jinja2>=3.1.2->flask==2.*->TTS) (2.1.3)
# Requirement already satisfied: six in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from jsonlines~=1.2.0->gruut[de,es,fr]==2.2.3->TTS) (1.16.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from pooch>=1.0->librosa==0.10.*->TTS) (3.11.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from requests->transformers==4.33.*->TTS) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from requests->transformers==4.33.*->TTS) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from requests->transformers==4.33.*->TTS) (2023.7.22)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.1/53.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>2.4.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from jsonmerge->k-diffusion->TTS) (4.19.2)
# Collecting imageio>=2.27
#   Downloading imageio-2.31.6-py3-none-any.whl (313 kB)
#      -------------------------------------- 313.2/313.2 kB 2.2 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2023.9.26-py3-none-any.whl (222 kB)
#      ------------------------------------- 222.9/222.9 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from sympy->torch>=1.7->TTS) (1.3.0)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      -------------------------------------- 130.2/130.2 kB 7.5 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.59.0-cp311-cp311-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 19.5 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
#      ------------------------------------- 182.3/182.3 kB 10.8 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<2,>=0.5
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.5-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.7/101.7 kB 6.1 MB/s eta 0:00:00
# Collecting protobuf<4.24,>=3.19.6
#   Downloading protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
#      ------------------------------------- 422.5/422.5 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from tensorboard->trainer->TTS) (65.5.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ------------------------------------- 190.6/190.6 kB 12.0 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ------------------------------------- 241.0/241.0 kB 15.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting setproctitle
#   Downloading setproctitle-1.3.3-cp311-cp311-win_amd64.whl (11 kB)
# Collecting appdirs>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ---------------------------------------- 181.3/181.3 kB ? eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-10.0.1-cp311-cp311-win_amd64.whl (2.5 MB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->TTS) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->TTS) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->TTS) (0.10.6)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\ajfon\documents\virtuals\text_to_audio\lib\site-packages (from ftfy->clip-anytorch->k-diffusion->TTS) (0.2.8)
# Collecting tzdata
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------- 341.8/341.8 kB 20.7 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.9/83.9 kB 1.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: TTS
#   Building wheel for TTS (pyproject.toml): started
#   Building wheel for TTS (pyproject.toml): finished with status 'done'
#   Created wheel for TTS: filename=TTS-0.19.1-cp311-cp311-win_amd64.whl size=909778 sha256=9018845ed733444ce58bb0fed5a8c2ed64b2cb91d6db71947ff5a8826eb4cd27
#   Stored in directory: c:\users\ajfon\appdata\local\pip\cache\wheels\72\0d\28\26df7ffb375a2ed06bf51b2cc85d9f1ae9e25991886b7b2932
# Successfully built TTS
# Installing collected packages: trampoline, tokenizers, pytz, python-crfsuite, pathtools, jieba, jamo, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, docopt, bnunicodenormalizer, bnnumerizer, bangla, appdirs, Werkzeug, unidecode, tzdata, tqdm, threadpoolctl, tensorboard-data-server, smmap, setproctitle, sentry-sdk, pysbd, pypinyin, pyparsing, pyasn1, protobuf, pillow, packaging, oauthlib, numpy, num2words, networkx, multidict, msgpack, markdown, llvmlite, lazy-loader, kiwisolver, jsonlines, joblib, itsdangerous, inflect, gruut-ipa, grpcio, ftfy, fsspec, frozenlist, fonttools, einops, docker-pycreds, cython, cycler, coqpit, click, cachetools, blinker, audioread, async-timeout, anyascii, absl-py, yarl, tzlocal, tifffile, soxr, soundfile, rsa, requests-oauthlib, pyasn1-modules, pooch, pandas, numba, nltk, imageio, gitdb, flask, contourpy, aiosignal, transformers, torchvision, torchsde, torchdiffeq, scikit-learn, scikit-image, matplotlib, kornia, google-auth, GitPython, g2pkk, dctorch, dateparser, aiohttp, accelerate, wandb, pynndescent, librosa, jsonmerge, gruut, google-auth-oauthlib, clip-anytorch, clean-fid, umap-learn, tensorboard, k-diffusion, trainer, TTS
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\ajfon\\Documents\\virtuals\\text_to_audio\\Lib\\site-packages\\~okenizers\\tokenizers.cp311-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
